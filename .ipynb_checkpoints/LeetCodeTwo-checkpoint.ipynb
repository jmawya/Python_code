# %%
class Twoesu:
     def eqro(self,ead):
         roman={
             'I': 1,
             'V': 5,
             'X': 10,
             'L': 50,
             'C': 100,
             'D': 500,
             'M':1000,
         }
         e=0
         for i in range(len(ead)):
             if i+1 <len(ead) and roman[ead[i]]<roman[ead[i+1]]:
                 e=e-roman[ead[i]]
             else:
                 e=e+roman[ead[i]]
         return e
sd=Twoesu()
ead="IX"
print(sd.eqro(ead))
# Out:
# 9

# %%
class Solution(object):
    def romanToInt(self, sod):
        word={}
        for i in sod:
            if i in word:
                word[i]=word[i]+1
            else:
                word[i]=1
        return word
cd=Solution()
sod="Tsswt"
print(cd.romanToInt(sod))
# Out:
# {'T': 1, 's': 2, 'w': 1, 't': 1}

# %%
class Solution(object):
    def romanToInt(self, sod):
        word={}
        for i in sod:
            if i in word:
                word[i]=word[i]+1
            else:
                word[i]=1
        re=[]
        for i in word:
            if word[i]==1:
                re.append(i)
        return re
cd=Solution()
sod="Tsswt"
print(cd.romanToInt(sod))
# Out:
# ['T', 'w', 't']

# %%
class Solution(object):
    def romanToInt(self, sod):
        e='*'
        for i in range(1,6):
             print(e*i)
cd=Solution()
sod=range(1,6)
cd.romanToInt(sod)
# Out:
# *
# **
# ***
# ****
# *****

# %%
e='*'
for i in range(1,6):
    print(e*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
class Solution(object):
    def romanToInt(self, sod):
        n=5
        for i in range(1,n+1):
             print(' '*(n-i)+'* '*i)
cd=Solution()
sod=range(1,6)
cd.romanToInt(sod)
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
class Solution(object):
    def romanToInt(self, sod):
        n=5
        for i in range(1,n+1):
            print('*'*(n-i)+'*'*i)
cd=Solution()
sod=range(1,6)
cd.romanToInt(sod)
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
class Solution(object):
    def reverse(self, x):
        original = x
        x = abs(x)
        e = 0
        while x > 0:
            e = e * 10 + x % 10
            x = x // 10

        if original < 0:
            e = -e

        # 32-bit signed integer check
        if e < -2**31 or e > 2**31 - 1:
            return 0

        return e

# Test
od = Solution()
x = 153423
print(od.reverse(x))  # 0, because it overflows
# Out:
# 324351

# %%
class Solution:
    def isPalindrome(self,x):
        y=""
        for i in str(x):
              y=i+y
        if str(x) == y :
            return True
        else:
             return False
sd=Solution()
print(sd.isPalindrome(121))
# Out:
# True

# %%
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution(object):
    def mergeTwoLists(self, list1, list2):
        if not list1:
            return list2
        if not list2:
            return list1

        if list1.val <= list2.val:
            list1.next = self.mergeTwoLists(list1.next, list2)
            return list1
        else:
            list2.next = self.mergeTwoLists(list1, list2.next)
            return list2


def build_linked_list(arr):
    dummy = ListNode(-1)
    curr = dummy
    for val in arr:
        curr.next = ListNode(val)
        curr = curr.next
    return dummy.next


def linked_list_to_list(head):
    result = []
    while head:
        result.append(head.val)
        head = head.next
    return result


# ---- Test ----
cd = Solution()

list1 = build_linked_list([1, 2, 4])
list2 = build_linked_list([1, 3, 4])

merged = cd.mergeTwoLists(list1, list2)
print(linked_list_to_list(merged))
# Out:
# [1, 1, 2, 3, 4, 4]

# %%
class Solution:
    def removenumber(self, nums):
        if not nums:
            return 0
        e=0
        for i in range(1,len(nums)):
            if nums[i]!=nums[e]:
                e+=1
                #e=e+1
                nums[e]=nums[i]
        return e+1
ed=Solution()
nums=[1,1,5]
print(ed.removenumber(nums))
# Out:
# 2

# %%
class Solution:
        def removenumber(self, nums,dk):
             e=0
             for i in range(len(nums)-len(dk)+1):
                   if nums[i:i+len(dk)]==dk:
                       return i
             else:
                 return -1
                
ed=Solution()
nums='subdlaen'
dk='aen'
print(ed.removenumber(nums,dk))
# Out:
# 5

# %%
class Solution:
        def removenumber(self, nums,dk):
             e=0
             for i in range(len(nums)):
                   if nums[i]!=dk:
                       nums[e]=nums[i]
                       e=e+1
             return e
        
                
ed=Solution()
nums=[1,1,5,8,9,7]
dk=1
print(ed.removenumber(nums,dk))
# Out:
# 4

# %%
class Solution(object):
    def searchInsert(self, nums, target):
       if target not in nums:
           nums.append(target)
       nums.sort()
       for i in range(len(nums)):
            if nums[i]==target:
                return i
        
sd=Solution()
nums = [3,6,7,8,10]
target = 5
print(sd.searchInsert(nums,target))
# Out:
# 1

# %%
'''Given an array of integers nums sorted in non-decreasing order, find the starting and ending position of a given target value.
If target is not found in the array, return [-1, -1].
You must write an algorithm with O(log n) runtime complexity.
'''
class Solution(object):
    def searchInsert(self, nums, target):
       pos=[]
       for i in range(len(nums)):
           if nums[i]==target:
               pos.append(i)

       if len(pos)==1:
           pos.append(pos[0])
       elif len(pos)>=2:
           pos=[min(pos),max(pos)]
       elif len(pos)==0:
           return -1,-1
       
       return pos
sd=Solution()
nums = [5,7,7,7,10,5]
target = 5
print(sd.searchInsert(nums,target))
# Out:
# [0, 5]
